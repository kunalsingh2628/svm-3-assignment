# %%
##Q-1

# %%
In the context of predicting house prices using an SVM regression model, several regression metrics can be employed to evaluate the performance of the model. The choice of the metric depends on the specific goals and requirements of the task. Here are some commonly used regression metrics:

Mean Absolute Error (MAE):

Formula: 
�
�
�
=
1
�
∑
�
=
1
�
∣
�
�
−
�
^
�
∣
MAE= 
n
1
​
 ∑ 
i=1
n
​
 ∣y 
i
​
 − 
y
^
​
  
i
​
 ∣
Interpretation: MAE represents the average absolute difference between the predicted and actual values. It is easy to understand and provides a straightforward measure of prediction accuracy.
Mean Squared Error (MSE):

Formula: 
�
�
�
=
1
�
∑
�
=
1
�
(
�
�
−
�
^
�
)
2
MSE= 
n
1
​
 ∑ 
i=1
n
​
 (y 
i
​
 − 
y
^
​
  
i
​
 ) 
2
 
Interpretation: MSE penalizes larger errors more heavily than MAE. It is widely used but sensitive to outliers.
Root Mean Squared Error (RMSE):

Formula: 
�
�
�
�
=
�
�
�
RMSE= 
MSE
​
 
Interpretation: RMSE is the square root of MSE and provides a measure in the same units as the target variable. It is more interpretable than MSE.
R-squared (R2) Score:

Formula: 
�
2
=
1
−
∑
�
=
1
�
(
�
�
−
�
^
�
)
2
∑
�
=
1
�
(
�
�
−
�
ˉ
)
2
R 
2
 =1− 
∑ 
i=1
n
​
 (y 
i
​
 − 
y
ˉ
​
 ) 
2
 
∑ 
i=1
n
​
 (y 
i
​
 − 
y
^
​
  
i
​
 ) 
2
 
​
 
Interpretation: R-squared measures the proportion of the variance in the target variable that is predictable from the independent variables. A higher R-squared value indicates a better fit.
In the case of predicting house prices, Mean Absolute Error (MAE) and Root Mean Squared Error (RMSE) are commonly used because they provide a clear understanding of the average prediction error and how much the predictions deviate from the actual values. Choose the metric that aligns with the specific requirements and preferences for assessing the model's performance in the context of house price prediction.

# %%
##Q-2

# %%
If your goal is to predict the actual price of a house as accurately as possible, the metric that you should prioritize is Mean Squared Error (MSE). Here's why:

Mean Squared Error (MSE):

Formula: 
�
�
�
=
1
�
∑
�
=
1
�
(
�
�
−
�
^
�
)
2
MSE= 
n
1
​
 ∑ 
i=1
n
​
 (y 
i
​
 − 
y
^
​
  
i
​
 ) 
2
 
Interpretation: MSE measures the average squared difference between the predicted and actual values. It penalizes larger errors more heavily.
In the context of house price prediction:

Minimizing MSE means reducing the average squared difference between predicted and actual house prices.
MSE provides a clear measure of the average magnitude of errors, and minimizing it is equivalent to finding predictions that are close to the actual prices.
R-squared (R2) Score:

Formula: 
�
2
=
1
−
∑
�
=
1
�
(
�
�
−
�
^
�
)
2
∑
�
=
1
�
(
�
�
−
�
ˉ
)
2
R 
2
 =1− 
∑ 
i=1
n
​
 (y 
i
​
 − 
y
ˉ
​
 ) 
2
 
∑ 
i=1
n
​
 (y 
i
​
 − 
y
^
​
  
i
​
 ) 
2
 
​
 
Interpretation: R-squared measures the proportion of the variance in the target variable that is predictable from the independent variables.
In the context of house price prediction:

While R-squared is a valuable metric for understanding the proportion of variance explained, it may not directly align with the goal of minimizing prediction errors in terms of the actual price.
R-squared does not provide information about the magnitude of errors in the same way as MSE.
In summary, when the primary goal is to predict the actual price of a house as accurately as possible, MSE is more appropriate as it directly quantifies the average squared difference between predictions and actual prices, making it a suitable choice for regression tasks where precise prediction accuracy is crucial.

# %%
##Q-3

# %%
When dealing with a dataset that has a significant number of outliers, the most appropriate regression metric is often the Mean Absolute Error (MAE). Here's why:

Mean Absolute Error (MAE):

Formula: 
�
�
�
=
1
�
∑
�
=
1
�
∣
�
�
−
�
^
�
∣
MAE= 
n
1
​
 ∑ 
i=1
n
​
 ∣y 
i
​
 − 
y
^
​
  
i
​
 ∣
Interpretation: MAE measures the average absolute difference between the predicted and actual values.
In the context of a dataset with outliers:

MAE is less sensitive to outliers compared to Mean Squared Error (MSE) and Root Mean Squared Error (RMSE).
Since MAE takes the absolute values of the differences, it does not heavily penalize large errors caused by outliers.
Advantages of MAE in the Presence of Outliers:

Outliers have a limited impact on the overall MAE, making it a robust metric in the presence of extreme values.
MAE provides a more robust measure of central tendency because it is less influenced by extreme values.
While Mean Squared Error (MSE) and Root Mean Squared Error (RMSE) tend to amplify the impact of outliers due to the squaring operation, MAE provides a more reliable assessment of prediction accuracy when dealing with datasets that exhibit a significant number of outliers.

# %%
##Q-4

# %%
When you have built an SVM regression model using a polynomial kernel and both Mean Squared Error (MSE) and Root Mean Squared Error (RMSE) are very close, you can typically choose either metric, as they provide similar information with slight differences in scale. Here are some considerations:

MSE (Mean Squared Error):

Formula: 
�
�
�
=
1
�
∑
�
=
1
�
(
�
�
−
�
^
�
)
2
MSE= 
n
1
​
 ∑ 
i=1
n
​
 (y 
i
​
 − 
y
^
​
  
i
​
 ) 
2
 
Interpretation: MSE measures the average squared difference between predicted and actual values.
Advantage: Provides a straightforward measure of prediction accuracy, and differences between models are easy to interpret.
RMSE (Root Mean Squared Error):

Formula: 
�
�
�
�
=
�
�
�
RMSE= 
MSE
​
 
Interpretation: RMSE is the square root of MSE, providing a measure in the same units as the target variable.
Advantage: RMSE is more interpretable than MSE, as it is in the same units as the target variable.
Choosing between MSE and RMSE often depends on your preference for interpretation. If you prefer a metric in the original units of the target variable, RMSE might be more intuitive. However, if you find the squared nature of MSE more convenient or if you are comparing models, either metric can be used.

In summary, since MSE and RMSE are very close and offer similar insights, you can choose either one based on your preference for interpretation or ease of communication.

# %%
##Q-5
